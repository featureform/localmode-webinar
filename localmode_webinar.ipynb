# %% [markdown]
# # Install and Instatiate Featureform

# %%
# !pip install featureform==1.10.3
# Out:
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/six-1.16.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pycparser-2.21-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/six-1.16.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pycparser-2.21-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/cffi-1.15.1-py3.11.egg-info due to invalid metadata entry 'name'
# Collecting featureform==1.10.3
#   Downloading featureform-1.10.3-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 2.4 MB/s eta 0:00:00a 0:00:010m
# Requirement already satisfied: click>=7.1.2 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (8.1.3)
# Requirement already satisfied: protobuf>=3.20.0 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (4.23.3)
# Requirement already satisfied: typeguard<3.0.0 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (2.13.3)
# Requirement already satisfied: grpcio>=1.47.0 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (1.54.2)
# Requirement already satisfied: numpy>=1.21.6 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (1.24.2)
# Requirement already satisfied: pandas==1.3.5 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (1.3.5)
# Requirement already satisfied: pandasql>=0.7.3 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (0.7.3)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (4.6.3)
# Requirement already satisfied: dataclasses==0.6 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (0.6)
# Requirement already satisfied: flask==2.2.1 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (2.2.1)
# Requirement already satisfied: Flask-Cors==3.0.10 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (3.0.10)
# Requirement already satisfied: validators>=0.20.0 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (0.20.0)
# Requirement already satisfied: dill==0.3.7 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (0.3.7)
# Requirement already satisfied: sqlalchemy<2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (1.4.48)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (2.31.0)
# Requirement already satisfied: rich in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (13.4.2)
# Requirement already satisfied: pyarrow in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (12.0.1)
# Requirement already satisfied: fastparquet in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (0.8.3)
# Requirement already satisfied: pinecone-client in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (2.2.2)
# Requirement already satisfied: weaviate-client in /opt/homebrew/lib/python3.11/site-packages (from featureform==1.10.3) (3.20.1)
# Requirement already satisfied: Werkzeug>=2.2.0 in /opt/homebrew/lib/python3.11/site-packages (from flask==2.2.1->featureform==1.10.3) (2.3.6)
# Requirement already satisfied: Jinja2>=3.0 in /opt/homebrew/lib/python3.11/site-packages (from flask==2.2.1->featureform==1.10.3) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from flask==2.2.1->featureform==1.10.3) (2.1.2)
# Requirement already satisfied: Six in /opt/homebrew/lib/python3.11/site-packages (from Flask-Cors==3.0.10->featureform==1.10.3) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/homebrew/lib/python3.11/site-packages (from pandas==1.3.5->featureform==1.10.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/homebrew/lib/python3.11/site-packages (from pandas==1.3.5->featureform==1.10.3) (2023.3)
# Requirement already satisfied: decorator>=3.4.0 in /opt/homebrew/lib/python3.11/site-packages (from validators>=0.20.0->featureform==1.10.3) (5.1.1)
# Requirement already satisfied: cramjam>=2.3.0 in /opt/homebrew/lib/python3.11/site-packages (from fastparquet->featureform==1.10.3) (2.6.2)
# Requirement already satisfied: fsspec in /opt/homebrew/lib/python3.11/site-packages (from fastparquet->featureform==1.10.3) (2023.6.0)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.11/site-packages (from fastparquet->featureform==1.10.3) (23.1)
# Requirement already satisfied: pyyaml>=5.4 in /opt/homebrew/lib/python3.11/site-packages (from pinecone-client->featureform==1.10.3) (6.0)
# Requirement already satisfied: loguru>=0.5.0 in /opt/homebrew/lib/python3.11/site-packages (from pinecone-client->featureform==1.10.3) (0.7.0)
# Requirement already satisfied: dnspython>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from pinecone-client->featureform==1.10.3) (2.3.0)
# Requirement already satisfied: urllib3>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from pinecone-client->featureform==1.10.3) (2.0.3)
# Requirement already satisfied: tqdm>=4.64.1 in /opt/homebrew/lib/python3.11/site-packages (from pinecone-client->featureform==1.10.3) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests->featureform==1.10.3) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests->featureform==1.10.3) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests->featureform==1.10.3) (2023.5.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/lib/python3.11/site-packages (from rich->featureform==1.10.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/lib/python3.11/site-packages (from rich->featureform==1.10.3) (2.15.1)
# Requirement already satisfied: authlib>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from weaviate-client->featureform==1.10.3) (1.2.0)
# Requirement already satisfied: cryptography>=3.2 in /opt/homebrew/lib/python3.11/site-packages (from authlib>=1.1.0->weaviate-client->featureform==1.10.3) (41.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.11/site-packages (from Jinja2>=3.0->flask==2.2.1->featureform==1.10.3) (2.1.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->featureform==1.10.3) (0.1.2)
# Requirement already satisfied: cffi>=1.12 in /opt/homebrew/lib/python3.11/site-packages (from cryptography>=3.2->authlib>=1.1.0->weaviate-client->featureform==1.10.3) (1.15.1)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.2->authlib>=1.1.0->weaviate-client->featureform==1.10.3) (2.21)
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/six-1.16.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pycparser-2.21-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/cffi-1.15.1-py3.11.egg-info due to invalid metadata entry 'name'
# Installing collected packages: featureform
#   Attempting uninstall: featureform
#     WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/six-1.16.0-py3.11.egg-info due to invalid metadata entry 'name'
#     Found existing installation: featureform 1.10.3rc0
#     Uninstalling featureform-1.10.3rc0:
#       Successfully uninstalled featureform-1.10.3rc0
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/six-1.16.0-py3.11.egg-info due to invalid metadata entry 'name'
# Successfully installed featureform-1.10.3
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/six-1.16.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/pycparser-2.21-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/six-1.16.0-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /opt/homebrew/lib/python3.11/site-packages/six-1.16.0-py3.11.egg-info due to invalid metadata entry 'name'
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
from featureform import local
import featureform as ff

client = ff.Client(local=True)

# %% [markdown]
# # Set a run name, to group everything we build in this notebook
#
# everything in featureform is versioned. We generate a default version when its not specificfied, but you can set the default version by using `set_run()`

# %%
ff.set_run("webinar")

# %% [markdown]
# # Register and read our primary dataset

# %%
transactions = local.register_file("transactions", path="./transactions_new.csv")

# %%
client.dataframe("transactions", ff.get_run())
# Out:
# Applying Run: webinar
# Creating provider local-mode
# Creating source transactions  webinar
#          Unnamed: 0 TransactionID CustomerID CustomerDOB   CustLocation  \
# 0                 0            T1   C5841053     10/1/94     JAMSHEDPUR
# 1                 1            T2   C2142763      4/4/57        JHAJJAR
# 2                 2            T3   C4417068    26/11/96         MUMBAI
# 3                 3            T4   C5342380     14/9/73         MUMBAI
# 4                 4            T5   C9031234     24/3/88    NAVI MUMBAI
# ...             ...           ...        ...         ...            ...
# 1046193     1048562      T1048563   C8020229      8/4/90      NEW DELHI
# 1046194     1048563      T1048564   C6459278     20/2/92         NASHIK
# 1046195     1048564      T1048565   C6412354     18/5/89      HYDERABAD
# 1046196     1048565      T1048566   C6420483     30/8/78  VISAKHAPATNAM
# 1046197     1048566      T1048567   C8337524      5/3/84           PUNE
#
#          CustAccountBalance  TransactionAmount            Timestamp  IsFraud
# 0                  17819.05               25.0  2022-04-09 11:33:09    False
# 1                   2270.69            27999.0  2022-03-27 01:04:21     True
# 2                  17874.44              459.0  2022-04-07 00:48:14    False
# 3                 866503.21             2060.0  2022-04-14 07:56:59     True
# 4                   6714.43             1762.5  2022-04-13 07:39:19    False
# ...                     ...                ...                  ...      ...
# 1046193             7635.19              799.0  2022-04-02 05:12:36    False
# 1046194            27311.42              460.0  2022-04-23 03:58:33    False
# 1046195           221757.06              770.0  2022-04-01 15:08:34    False
# 1046196            10117.87             1000.0  2022-04-15 12:50:15    False
# 1046197            75734.42             1166.0  2022-03-30 20:56:02    False
#
# [1046198 rows x 9 columns]

# %% [markdown]
# # Create a percentage balance transformation for training and an equivalent ondemand feature for serving

# %%
@local.df_transformation(inputs=[("transactions", ff.get_run())])
def perc_balance(df):
    df["BalancePercent"] = df["TransactionAmount"]/df["CustAccountBalance"].replace(0.0, 1.0)
    return df

client.dataframe(perc_balance)
# Out:
# Applying Run: webinar
# Creating provider local-mode
# Creating source perc_balance  webinar
#          Unnamed: 0 TransactionID CustomerID CustomerDOB   CustLocation  \
# 0                 0            T1   C5841053     10/1/94     JAMSHEDPUR
# 1                 1            T2   C2142763      4/4/57        JHAJJAR
# 2                 2            T3   C4417068    26/11/96         MUMBAI
# 3                 3            T4   C5342380     14/9/73         MUMBAI
# 4                 4            T5   C9031234     24/3/88    NAVI MUMBAI
# ...             ...           ...        ...         ...            ...
# 1046193     1048562      T1048563   C8020229      8/4/90      NEW DELHI
# 1046194     1048563      T1048564   C6459278     20/2/92         NASHIK
# 1046195     1048564      T1048565   C6412354     18/5/89      HYDERABAD
# 1046196     1048565      T1048566   C6420483     30/8/78  VISAKHAPATNAM
# 1046197     1048566      T1048567   C8337524      5/3/84           PUNE
#
#          CustAccountBalance  TransactionAmount            Timestamp  IsFraud  \
# 0                  17819.05               25.0  2022-04-09 11:33:09    False
# 1                   2270.69            27999.0  2022-03-27 01:04:21     True
# 2                  17874.44              459.0  2022-04-07 00:48:14    False
# 3                 866503.21             2060.0  2022-04-14 07:56:59     True
# 4                   6714.43             1762.5  2022-04-13 07:39:19    False
# ...                     ...                ...                  ...      ...
# 1046193             7635.19              799.0  2022-04-02 05:12:36    False
# 1046194            27311.42              460.0  2022-04-23 03:58:33    False
# 1046195           221757.06              770.0  2022-04-01 15:08:34    False
# 1046196            10117.87             1000.0  2022-04-15 12:50:15    False
# 1046197            75734.42             1166.0  2022-03-30 20:56:02    False
#
#          BalancePercent
# 0              0.001403
# 1             12.330613
# 2              0.025679
# 3              0.002377
# 4              0.262494
# ...                 ...
# 1046193        0.104647
# 1046194        0.016843
# 1046195        0.003472
# 1046196        0.098835
# 1046197        0.015396
#
# [1046198 rows x 10 columns]

# %% [markdown]
# # Create a rolling window average of transactions

# %%
@local.df_transformation(inputs=[("transactions", ff.get_run())])
def window_aggs(df):
    df['Timestamp'] = pd.to_datetime(df['Timestamp'])
    df = df.sort_values(by='Timestamp')
    df.set_index('Timestamp', inplace=True)
    return df.groupby('CustomerID')['TransactionAmount'].rolling(window=30, min_periods=1).agg(["mean", "count"]).reset_index()


client.dataframe(window_aggs)
# Out:
# Applying Run: webinar
# Creating provider local-mode
# Creating source window_aggs  webinar
#         CustomerID           Timestamp    mean  count
# 0         C1010011 2022-03-31 12:25:23  4750.0    1.0
# 1         C1010011 2022-04-20 22:31:25  2553.0    2.0
# 2         C1010012 2022-04-19 23:53:55  1499.0    1.0
# 3         C1010014 2022-04-06 19:57:12   250.0    1.0
# 4         C1010014 2022-04-17 18:49:18   727.5    2.0
# ...            ...                 ...     ...    ...
# 1046193   C9099836 2022-04-22 09:31:33   691.0    1.0
# 1046194   C9099877 2022-04-24 14:31:31   222.0    1.0
# 1046195   C9099919 2022-04-13 07:42:36   126.0    1.0
# 1046196   C9099941 2022-04-17 17:56:18    50.0    1.0
# 1046197   C9099956 2022-04-02 19:54:20   855.0    1.0
#
# [1046198 rows x 4 columns]

# %% [markdown]
# # Defining our features, label, and training set

# %%
@ff.entity
class User:
    is_fraud = ff.Label(transactions[["CustomerID", "IsFraud", "Timestamp"]], type=ff.Bool)
    avg_trans = ff.Feature(window_aggs[["CustomerID", "mean", "Timestamp"]], type=ff.Float32)
    balance = ff.Feature(transactions[["CustomerID", "CustAccountBalance", "Timestamp"]], type=ff.Float32)
    perc = ff.Feature(perc_balance[["CustomerID", "BalancePercent", "Timestamp"]], type=ff.Float32)
    
ts = ff.register_training_set("fraud", label=User.is_fraud, features=[("avg_trans", ff.get_run()), ("perc", ff.get_run())])

client.apply()
# Out:
# Applying Run: webinar
# Creating provider local-mode
# Creating entity user
# Creating feature avg_trans  webinar
# Creating feature balance  webinar
# Creating feature perc  webinar
# Creating label is_fraud  webinar
# Creating training-set fraud  webinar
# Updating Feature Table: |##################################################| 100% Complete
#
# Updating Feature Table: |##################################################| 100% Complete
#
# Updating Feature Table: |##################################################| 100% Complete

# %% [markdown]
# # Training a Model

# %%
ts = client.training_set("fraud", "webinar").dataframe()
print(ts)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

X = ts.drop('label', axis=1)
y = ts['label']
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9805247562607532

# %% [markdown]
# # Serving for Inference / Prod

# %%
@ff.ondemand_feature()
def ondemand_percent(client, params, entities):
    return params["TransactionAmount"] / client.features([("balance", "webinar")], entities=entities)[0]

client.apply()
# Out:
# Applying Run: webinar
# Creating provider local-mode
# Creating ondemand_feature ondemand_percent  webinar

# %%
f = client.features([("avg_trans", "webinar"), ("ondemand_percent", ff.get_run())],
                params={"TransactionAmount": 1000.0},
                entities={"user": "C1010011"})
rf.predict([f])
# Out:
# Updating Feature Table: |##################################################| 100% Complete
# UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# array([ True])
